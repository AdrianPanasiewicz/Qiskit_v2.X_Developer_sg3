# %% [markdown]
# ## Practice Questions

# %% [markdown]
# **1) What is the effect of calling `qc.barrier()` on a quantum circuit `qc`?**

# %% [markdown]
# A) It only adds a visual separator to the circuit.
#
# B) It raises an error because `qc.barrier()` requires a qubit register argument.
#
# C) It inserts a barrier that prevents the transpiler from reordering or combining gates across that point in the circuit.
#
# D) It raises an error because the correct way to add a barrier is `qc.append(barrier())`

# %% [markdown]
# ***Answer:***
# <Details>
# <br/>
# C) It adds a barrier such that during transpilation gates on each site of the barrier does not get mixed
#
#
#
# </Details>

# %% [markdown]
# ---

# %% [markdown]
# **2. Which method of drawing a timeline diagram is correct?**
#
# A)
# ```
# from qiskit.visualization.timeline import draw
#
# qc = QuantumCircuit(2)
# qc.h(0)
# qc.cx(0,1)
#
# qc = transpile(qc, backend, layout_method='trivial')
# draw(qc)
# ```
#
# B)
# ```
# from qiskit.visualization.timeline import draw
#
# qc = QuantumCircuit(2)
# qc.h(0)
# qc.cx(0,1)
#
# backend = GenericBackendV2(5)
#
# qc = transpile(qc, backend, layout_method='trivial')
# draw(target=qc, backend=backend.target)
# ```
#
# C)
# ```
# qc = QuantumCircuit(2)
# qc.h(0)
# qc.cx(0,1)
#
# backend = GenericBackendV2(5)
#
# qc = transpile(qc, backend, layout_method='trivial')
# qc.draw(method="timeline")
# ```
#
# D)
# ```
# from qiskit.visualization.timeline import draw
#
# qc = QuantumCircuit(2)
# qc.h(0)
# qc.cx(0,1)
#
# backend = GenericBackendV2(5)
#
# qc = transpile(qc, backend, layout_method='trivial')
# draw(qc, target=backend.target)
# ```

# %% [markdown]
# ***Answer:***
# <Details>
# <br/>
# D)
# ```
# from qiskit.visualization.timeline import draw
#
# qc = QuantumCircuit(2)
# qc.h(0)
# qc.cx(0,1)
#
# backend = GenericBackendV2(5)
#
# qc = transpile(qc, backend, layout_method='trivial')
# draw(qc, target=backend.target)
# ```
# </Details>

# %% [markdown]
# ---

# %% [markdown]
# **3. Which Qiskit visualization is used to display how logical (virtual) qubits are mapped onto physical qubits of a backend?**

# %% [markdown]
# A) Qsphere visualization
#
# B) Gate map visualization
#
# C) DAG visualization
#
# D) Hinton diagram

# %% [markdown]
# ***Answer:***
# <Details>
# <br/>
# B) Gate map visualization
# </Details>
