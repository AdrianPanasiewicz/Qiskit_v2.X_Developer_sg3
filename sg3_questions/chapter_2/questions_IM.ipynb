# %% [markdown]
# ## Practice Questions

# %% [markdown]
# **1) Which statement about qiskit.visualization module is TRUE?**

# %% [markdown]
# A)  It only visualizes quantum states
#
# B)  It visualizes counts, states, circuits, and devices
#
# C)  It works without any additional dependencies
#
# D)  It only works in Jupyter notebooks

# %% [markdown]
# ***Answer:***
# <Details>
# <br/>
# B)  It visualizes counts, states, circuits, and devices
#
#
#
# </Details>

# %% [markdown]
# ---

# %% [markdown]
# **2. What does each Bloch sphere represent in ```plot_bloch_multivector(state)```?**
#
# A)  Entire multi-qubit state
#
# B)  Reduced density matrix
#
# C)  Expectation values of Pauli X, Y, Z on that qubit
#
# D)  Measurement probabilities

# %% [markdown]
# ***Answer:***
# <Details>
# <br/>
# C)  Expectation values of Pauli X, Y, Z on that qubit
# </Details>

# %% [markdown]
# ---

# %% [markdown]
# **3. What is plotted by ```plot_state_city(state)```?**

# %% [markdown]
# A)  Measurement counts
#
# B)  Real and imaginary parts of density matrix
#
# C)  Bloch vectors
#
# D)  Circuit diagram

# %% [markdown]
# ***Answer:***
# <Details>
# <br/>
# B)  Real and imaginary parts of density matrix
# </Details>
