# %% [markdown]
# 1. You have the Parameter value set being an array of dimensions (1,4) and the observables array being an array of (10,1) dimensions. What will be the dimensions of the Estimator Broadcasting estimates?
#
# A) 1x1
#
# B) 1x4
#
# C) 10x4
#
# D) 4x10
#
# E) None of the above

# %% [markdown]
# ***Answer:***
# <Details>
# <br/>
# C)  10x4
# </Details>

# %% [markdown]
# 2. You have a backend of 10 qubits. You want to run a circuit concerning only 1 qubit with an Estimator primitive. You transpiled the circuit and obtained the ISA observable which is `IIIXIIIIII`, `IIIZIIIIII`, with coeffs `[1.+0.j], [1+0.4.j]`. Why is this observable invalid?
#
# A) The number of backend qubits and the original circuit one are incompatible with each other
#
# B) Pauli strings can be composed only from the `I, X and Y` letters
#
# C) Coefficients must be real numbers
#
# D) None of the above

# %% [markdown]
# ***Answer:***
# <Details>
# <br/>
# C)  Coefficients must be real numbers
# </Details>

# %% [markdown]
# 3. The quantum circuit has been executed on estimator. You take a look at the first `PubResult` in the array of results. Let's say you store it in the variable named `data`. How can you check the standard error of the mean of expectation value estimates?
#
# A) `data.stde`
#
# B) `data.stds`
#
# C) `data.errors.stds`

# %% [markdown]
# ***Answer:***
# <Details>
# <br/>
# B) `data.stds`
# </Details>
