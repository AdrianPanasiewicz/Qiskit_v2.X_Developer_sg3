# %% [markdown]
# ## Practice Questions

# %% [markdown]
# **1. Which error suppression and error mitigation options are available for the Estimator primitive? Select all that apply.**

# %% [markdown]
# A) Zero-noise estimation
#
# B) Pauli Twirling
#
# C) Dynamical decoupling
#
# D) Twirling Readout Error Extinction (T-REx)

# %% [markdown]
# ***Answer:***
# <Details>
# <br/>
# A), B), C) and D) (All choices)
#
# </Details>

# %% [markdown]
# ---

# %% [markdown]
# **2. Which code snippet correctly submits a quantum circuit `qc` for estimating expectation value for `obs` on a specified `backend`?**
#
#
# A)
# ```
# obs = SparsePauliOp("ZZ")
# estimator = Estimator(backend=backend)
# job = estimator.run([qc, obs])
# ```
#
# B)
# ```
# obs = SparsePauliOp("ZZ")
# job = backend.run(qc, obs mode="estimator")
# ```
#
# C)
# ```
# obs = SparsePauliOp("ZZ")
# estimator = Estimator(backend=backend)
# job = estimator.run(qc, obs)
# ```
#
# D)
# ```
# obs = SparsePauliOp("ZZ")
# job = backend.run([qc, obs], mode="estimator")
# ```

# %% [markdown]
# ***Answer:***
# <Details>
# <br/>
# A)
# ```
# obs = SparsePauliOp("ZZ")
# estimator = Estimator(backend=backend)
# job = estimator.run([qc, obs])
# ```
#
# </Details>

# %% [markdown]
# ---

# %% [markdown]
# **3. Given a `estimator` instance, how would you enable Zero Noise Estimation and Twirling Readout Error Extinction (T-REx) options?**

# %% [markdown]
# A)
# ```
# estimator.options.resilience.zne_mitigation = True
# estimator.options.resilience.measure_mitigation = True
# ```
#
# B)
# ```
# estimator.resilience.zne_mitigation = True
# estimator.resilience.measure_mitigation = True
# ```
#
# C)
# ```
# estimator.zne_mitigation = True
# estimator.measure_mitigation = True
# ```
#
# D)
# ```
# estimator.options.zne_mitigation = True
# estimator.options.measure_mitigation = True
# ```

# %% [markdown]
# ***Answer:***
# <Details>
# <br/>
# A)
# ```
# estimator.options.resilience.zne_mitigation = True
# estimator.options.resilience.measure_mitigation = True
# ```
# </Details>
