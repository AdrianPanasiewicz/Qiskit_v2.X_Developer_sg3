# %% [markdown]
# 1. The tensor multiplications of A by B can be obtained by the `A.tensor(B)` command. How to perform the tensor multiplication of B by A?

# %% [markdown]
# A) `B.tensor(A)`
#
# B) `A.expand(B)`
#
# C) A,B
#
# D) None of the answers above are correct

# %% [markdown]
# 2. How to compute fidelity of two channels?

# %% [markdown]
# A) F = channel_fidelity(opA, opB)
#
# B) F  = process_fidelity(opA, opB)
#
# C) F = fidelity(opA, opB)

# %% [markdown]
# 3. Which of the classes below stores linear operators as density matrix?

# %% [markdown]
# A) SparsePauliOp
#
# B) Pauli
#
# C) Operator
