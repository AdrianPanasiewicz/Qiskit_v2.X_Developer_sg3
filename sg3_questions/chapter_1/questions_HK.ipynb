# %% [markdown]
# ## Practice Questions

# %% [markdown]
# **1) Which one of the following code fragments will generate the given output**

# %% [markdown]
# ```
# [[ 0.+0.j -1.+0.j  0.+0.j  0.+0.j]
#  [-1.+0.j  0.+0.j  0.+0.j  0.+0.j]
#  [ 0.+0.j  0.+0.j  0.+0.j  1.-0.j]
#  [ 0.+0.j  0.+0.j  1.-0.j  0.+0.j]]
#
# ```

# %% [markdown]
# A)
# ```
# p = Pauli('-XZ')
# print(p.to_matrix())
# ```
#
# B)
# ```
# p = Pauli('XZ')
# print(p.to_matrix())
# ```
#
# C)
# ```
# p = Pauli('-ZX')
# print(p.to_matrix())
# ```
#
# D)
# ```
# p = Pauli('ZX')
# print(p.to_matrix())
# ```

# %% [markdown]
# ***Answer:***
# <Details>
# <br/>
# C)
# ```
# p = Pauli('-ZX')
# print(p.to_matrix())
# ```
#
# </Details>

# %% [markdown]
# ---

# %% [markdown]
# **2. Given the following code fragment, what is the approximate probability that a measurement would result in a bit value of 0?**
#
# ```
# qc = QuantumCircuit(1)
# qc.reset(0)
# qc.rx(np.pi/2, 0)
# qc.rz(np.pi/2, 0)
# qc.ry(np.pi/2, 0)
# qc.measure_all()
# ```
#
# A) 1.0
#
# B) 0.5
#
# C) 0.8536
#
# D) 0.0

# %% [markdown]
# ***Answer:***
# <Details>
# <br/>
# D) 0
# </Details>

# %% [markdown]
# ---

# %% [markdown]
# **3. Given the image of this circuit, how to complete the code to make it looks the same?**
#
# ![HK_c1_3.png](q_photos/HK_c1_3.png)

# %% [markdown]
# A)
# ```
# qc = QuantumCircuit(3)
# qc.h(2)
# qc.cx(2, 1)
# qc.draw("mpl")
# ```
#
# B)
# ```
# qc = QuantumCircuit(3)
# qc.h(0)
# qc.cx(0, 1)
# qc.draw("mpl")
# ```
#
# C)
# ```
# qc = QuantumCircuit(3)
# qc.h(2)
# qc.cx(1, 2)
# qc.draw("mpl")
# ```
#
# D)
# ```
# qc = QuantumCircuit(3)
# qc.cx(2, 1)
# qc.h(2)
# qc.draw("mpl")
# ```

# %% [markdown]
# ***Answer:***
# <Details>
# <br/>
# A)
# ```
# qc = QuantumCircuit(3)
# qc.h(2)
# qc.cx(2, 1)
# qc.draw("mpl")
# ```
# </Details>
