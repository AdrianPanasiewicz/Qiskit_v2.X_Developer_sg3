# %% [markdown]
# 1. Can you use physical qubits inside the gate statements?
#
# A) Yes
#
# B) No

# %% [markdown]
# ***Answer:***
# <Details>
# <br/>
# B)  No
# </Details>

# %% [markdown]
# 2. You have a custom quantum gate that is constructed in QASM3. Assuming it is stored in a python variable named `special_gate`, how can you convert it to quantum circuit?
#
# A) ``` import qiskit.qasm3
#     qc = qiskit.qasm.convert(special_gate)```
#
# B) ``` qc = qiskit.loads_qasm3(special_gate)```
#
# C) ``` import qiskit.qasm3
#     qc = qiskit.qasm3.loads(special_gate)```

# %% [markdown]
# ***Answer:***
# <Details>
# <br/>
# C)  ``` import qiskit.qasm3
#     qc = qiskit.qasm3.loads(special_gate)```
# </Details>

# %% [markdown]
# 3. You want to write a quantum circuit in QASM. You know you will need only the commonly used gates like `X` or `CX`. What should you place at the beginning of your code?
#
# A) Nothing - standard gates are automatically imported
#
# B) `include "stdgates.inc";`
#
# C) `import "stdgates.inc";`
#
# D) `include "standardgates.inc";`

# %% [markdown]
# ***Answer:***
# <Details>
# <br/>
# B) `include "stdgates.inc";`
# </Details>
