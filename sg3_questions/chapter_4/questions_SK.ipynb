# %% [markdown]
# 1. Suppose you have a quantum circuit for finding a ground state energy of water. You would like to run this on a IBM quantum machine of your choice. What execution mode would you choose?
#
# A) Batch
#
# B) Job
#
# C) Session
#
# D) None of the above

# %% [markdown]
# ***Answer:***
# <Details>
# <br/>
# C) Session
# </Details>

# %% [markdown]
# 2. Suppose you are given the following piece of code concerning the running of EstimatorV2 :
# `job = estimator.run([(param_values, isa_circuit, isa_observable)])`
#
# Is this piece of code valid?
#
# A) Yes, because PUB has all of the elements
#
# B) Yes, because parameter values are provided
#
# C) No, as the order of the PUB elements is incorrect
#
# D) None of the above

# %% [markdown]
# ***Answer:***
# <Details>
# <br/>
# C) No, as the order of the PUB elements is incorrect
# </Details>

# %% [markdown]
# 3. You are asked to do the estimation of a quantum circuit. The backend you should use is provided by the external provider. You also know this provider implements `Backend` interface. What could you use to create the estimator out in this situation?
#
# A) EstimatorV2
#
# B) EstimatorBackendV2
#
# C) BackendSamplerV2
#
# D) BackendEstimatorV2
#
# E) ExternalEstimator

# %% [markdown]
# ***Answer:***
# <Details>
# <br/>
# D) BackendEstimatorV2
# </Details>
