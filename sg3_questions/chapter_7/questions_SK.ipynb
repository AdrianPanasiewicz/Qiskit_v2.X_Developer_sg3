# %% [markdown]
# 1. How do you save the job results to the disk with the use of Qiskit and Python?
#
# A) As a text file
#
# B) As a JSON file
#
# C) As an Avro file
#
# D) As an XML file

# %% [markdown]
# ***Answer:***
# <Details>
# <br/>
# B)  As a JSON file
# </Details>

# %% [markdown]
# 2. Suppose you have a system calling IBM Quantum computers every single day to perform analysis of a chemical molecule. You want to check all of the calls after 1st of April. What parameter of the `service.jobs` function can help you with this?
#
# A) created_after
#
# B) start_time
#
# C) time_interval

# %% [markdown]
# ***Answer:***
# <Details>
# <br/>
# A)  created_after
# </Details>

# %% [markdown]
# 3. Where can you check your job status?
#
# A) `job.status()` in python program
#
# B) `job.current_state()` in python program
#
# C) In the Workload table on IBM Quantum Platform

# %% [markdown]
# ***Answer:***
# <Details>
# <br/>
# A, C)  `job.status()` in python program and the workload table on IBM Quantum Platform
# </Details>
