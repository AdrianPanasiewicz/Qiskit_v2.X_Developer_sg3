# %% [markdown]
# ## Practice Questions

# %% [markdown]
# **1. Which of the following Qiskit code snippets correctly defines a single-qubit
# quantum circuit where the rotation angle $\theta$ of an RX gate is parameterized
# by the quadratic expression $\theta = x^2 + 2x + 1$?**

# %% [markdown]
# A)
# ```
# from qiskit.circuit import Parameter
#
# theta = Parameter("theta")
# x = Parameter("x")
# theta = x**2 + 2*x +1
#
# qc = QuantumCircuit(1)
# qc.rx(theta, 0)
# ```
#
# B)
# ```
# from qiskit.variational import Parameter
#
# x = Parameter("x")
# theta = x**2 + 2*x +1
#
# qc = QuantumCircuit(1)
# qc.rx(theta, 0)
# ```
#
# C)
# ```
# from qiskit.variational import Parameter
#
# x = Parameter("x")
# theta = x**2 + 2*x +1
#
# qc = QuantumCircuit(1)
# qc.rx(0, theta)
# ```
#
# D)
# ```
# from qiskit.circuit import Parameter
#
# x = Parameter("x")
# theta = x**2 + 2*x +1
#
# qc = QuantumCircuit(1)
# qc.rx(theta, 0)
# ```
#
# E)
# ```
# from qiskit.circuit import Parameter
#
# x = Parameter("x")
# theta = x**2 + 2*x +1
#
# qc = QuantumCircuit(1)
# qc.rx(0)
# qc.assign_parameters({rx:theta})
# ```

# %% [markdown]
# ***Answer:***
# <Details>
# <br/>
# D)
# ```
# from qiskit.circuit import Parameter
#
# x = Parameter("x")
# theta = x**2 + 2*x +1
#
# qc = QuantumCircuit(1)
# qc.rx(theta, 0)
# ```
#
# </Details>

# %% [markdown]
# ---

# %% [markdown]
# **2. In Qiskit, which of the following is the correct syntax to apply the sine function to a `Parameter` object named `phi`?**
#
#
# A) `expr = sin(phi)`
#
# B) `expr = phi.sin()`
#
# C) `expr = apply_sin(phi)`

# %% [markdown]
# ***Answer:***
# <Details>
# <br/>
# B)
# ```
# expr = phi.sin()
# ```
# </Details>

# %% [markdown]
# ---

# %% [markdown]
# **3. Which of the following Qiskit code snippets correctly transpiles a logical quantum circuit `qc` for execution on a specific physical `backend`?**

# %% [markdown]
# A)
# ```
# transpiled_qc = transpile(qc, backend=backend)
# ```
#
# B)
# ```
# pass_manager = generate_preset_pass_manager(backend=backend)
# transpiled_qc = pass_manager.transpile(qc)
# ```
#
# C)
# ```
# pass_manager = generate_preset_pass_manager(backend=backend)
# transpiled_qc = pass_manager.run(qc)
# ```
#
# D) Both A) and B) are correct
#
# E) Both A) and C) are correct

# %% [markdown]
# ***Answer:***
# <Details>
# <br/>
# E) Both A) and C) are correct
# </Details>
