# %% [markdown]
# ## Practice Questions

# %% [markdown]
# **1. Which code fragment is the incorrect way to initialized Quantum Circuit?**

# %% [markdown]
# A)
# ```
# qubits = QuantumRegister(2)
# clbits = ClassicalRegister(2)
# circuit = QuantumCircuit(qubits, clbits)
# ```
#
# B)
# ```
# circuit = QuantumCircuit(2, 2, 2, 2)
# ```
#
# C)
# ```
# qubits_1 = QuantumRegister(2)
# qubits_2 = QuantumRegister(2)
# clbits_1 = ClassicalRegister(2)
# clbits_2 = ClassicalRegister(2)
# circuit = QuantumCircuit(qubits_1, qubits_2, clbits_1, clbits_2)
# ```
#
# D)
# ```
# circuit = QuantumCircuit(2, 2)
# ```
#
# E)
# ```
# circuit = QuantumCircuit(2)
# ```

# %% [markdown]
# ***Answer:***
# <Details>
# <br/>
# B) circuit = QuantumCircuit(2, 2, 2, 2)
#
# </Details>

# %% [markdown]
# ---

# %% [markdown]
# **2. In Qiskit, which of the following is the incorrect stage of transpiler?**
#
#
# A) scheduling
#
# B) translation
#
# C) compiling
#
# D) optimization
#
# E) init
#
# F) layout

# %% [markdown]
# ***Answer:***
# <Details>
# <br/>
# C) Compiling
# </Details>

# %% [markdown]
# ---

# %% [markdown]
# **3. According to the Qiskit, what defines a circuit as being an ISA (Instruction Set Architecture) Circuit??**

# %% [markdown]
# A) The circuit has been decomposed into the backend's specific basis gates and mapped to the device's coupling map (physical qubit connectivity).
#
# B) The circuit uses `ClassicalRegister` objects instead of the new `expr.Var` system to ensure compatibility with older simulator versions.
#
# C) The circuit has been converted into a Pulse schedule (using Qiskit Pulse) to control the microwave pulses sent to the dilution refrigerator.
#
# D) The circuit's depth has been reduced to exactly 1 by using the BasisTranslator pass to merge all single-qubit rotations.

# %% [markdown]
# ***Answer:***
# <Details>
# <br/>
# A) The circuit has been decomposed into the backend's specific basis gates and mapped to the device's coupling map (physical qubit connectivity).
# </Details>
