# %% [markdown]
# 1. Suppose you're visualizing the quantum circuit with text. You want to limit the line length to 50 characters. Which of below would do that?

# %% [markdown]
# A) `circuit.draw(output="mpl")`
#
# B) `circuit.draw(output="text", truncate=True, max_width=50)`
#
# C) `circuit.draw(output="text", fold=50)`
#
# D) `circuit.draw(output="text", max_width=50)`

# %% [markdown]
# 2. How would you sort the sampling results of a bell state such that the first value sampled to the left of the visualization is 11 and the rightmost one is 00?

# %% [markdown]
# A) `sort="increasing"`
#
# B) `sort="asc"`
#
# C) `order="desc"`
#
# D) `order="decreasing"`
#
# E) None of the above

# %% [markdown]
# 3. You'd like to display a quantum state density matrix in such a way that you see separately real and imaginary amplitudes. What kinds of visualization would you choose?

# %% [markdown]
# A) QSphere
#
# B) Bloch Sphere
#
# C) City
#
# D) Hinton
#
# E) LaTex
